# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install openpyxl

# %%
df = pd.read_excel('n_movies.xlsx')

# %%
df.head()
# Out:
#             title  release_year  duration      genre  rating    votes  \
# 0       Cobra Kai          2018        30     Action     8.5   177031
# 1       The Crown          2016        58    History     8.7   199885
# 2     The Sandman          2022        45      Drama     7.8   116358
# 3  Rick and Morty          2013        23  Animation     9.2   502160
# 4    Breaking Bad          2008        49      Crime     9.5  1831340
#
#   main_production
# 0             EUA
# 1              UK
# 2              UK
# 3             EUA
# 4             EUA

# %%
eixo_x = df['genre'].value_counts().keys()
eixo_y = df['genre'].value_counts().values

# %%
eixo_y
# Out:
# array([4, 4, 2, 2, 2, 2, 2, 1, 1], dtype=int64)

# %%
plt.bar(eixo_x, eixo_y)
plt.title("Filmes por Gênero")
plt.xticks(rotation = 45)
plt.xlabel("Gênero")
plt.ylabel('Quantidade')
plt.show()

# %%
eixo_x2 = df['release_year'].value_counts().sort_index().keys()
eixo_y2 = df['release_year'].value_counts().sort_index().values

# %%
plt.plot(eixo_x2, eixo_y2)
plt.title("Quantidade de Filmes por ano de Lançamento")
plt.xlabel('Ano de Lançamento')
plt.ylabel('Quantidade de Filmes')
plt.show()
